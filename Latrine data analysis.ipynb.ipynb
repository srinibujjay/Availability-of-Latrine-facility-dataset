# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
df = pd.read_excel('Availability of type of Latrine Facility Table For India.xls', sheet_name='Sheet1')

# %%
print("Column headings:")
print(df.columns)
# Out:
# Column headings:
# Index(['State Code', 'Area Name', 'Sector', 'Total House', 'latrine inhouse',
#        'FP sewer system', 'FP septic tank', 'Flush other', 'Pit with slab',
#        'pit without slab', 'Disposal to open drain',
#        'Night soil removed by human', 'Night soil removed by animal',
#        'No latrine within premises', 'Pubilc latrine', 'Open latrine'],
#       dtype='object')

# %%
df.shape # info no of rows and column
# Out:
# (94, 16)

# %%
df.ndim # no of dimensions
# Out:
# 2

# %%
df.head(7)
# Out:
#    State Code                Area Name Sector  Total House  latrine inhouse  \
# 0         NaN                      NaN    NaN          NaN              NaN
# 1         NaN                      NaN    NaN          NaN              NaN
# 2         NaN                      NaN    NaN          NaN              NaN
# 3         NaN                      NaN    NaN          NaN              NaN
# 4         1.0  STATE - JAMMU & KASHMIR  Total     262419.0          70103.0
# 5         1.0  STATE - JAMMU & KASHMIR  Rural     243707.0          56070.0
# 6         1.0  STATE - JAMMU & KASHMIR  Urban      18712.0          14033.0
#
#    FP sewer system  FP septic tank  Flush other  Pit with slab  \
# 0              NaN             NaN          NaN            NaN
# 1              NaN             NaN          NaN            NaN
# 2              NaN             NaN          NaN            NaN
# 3              NaN             NaN          NaN            NaN
# ...

# %%
df.dtypes
# Out:
# State Code                      float64
# Area Name                        object
# Sector                           object
# Total House                     float64
# latrine inhouse                 float64
# FP sewer system                 float64
# FP septic tank                  float64
# Flush other                     float64
# Pit with slab                   float64
# pit without slab                float64
# Disposal to open drain          float64
# Night soil removed by human     float64
# Night soil removed by animal    float64
# No latrine within premises      float64
# Pubilc latrine                  float64
# Open latrine                    float64
# dtype: object

# %%
df['Open latrine'].describe()
# Out:
# count    9.000000e+01
# mean     3.874159e+05
# std      6.624228e+05
# min      1.100000e+01
# 25%      4.835500e+03
# 50%      5.605250e+04
# 75%      3.566822e+05
# max      2.919694e+06
# Name: Open latrine, dtype: float64

# %%
df.iloc[0:4, :]
# Out:
#    State Code Area Name Sector  Total House  latrine inhouse  FP sewer system  \
# 0         NaN       NaN    NaN          NaN              NaN              NaN
# 1         NaN       NaN    NaN          NaN              NaN              NaN
# 2         NaN       NaN    NaN          NaN              NaN              NaN
# 3         NaN       NaN    NaN          NaN              NaN              NaN
#
#    FP septic tank  Flush other  Pit with slab  pit without slab  \
# 0             NaN          NaN            NaN               NaN
# 1             NaN          NaN            NaN               NaN
# 2             NaN          NaN            NaN               NaN
# 3             NaN          NaN            NaN               NaN
#
#    Disposal to open drain  Night soil removed by human  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# ...

# %%
df.head()
# Out:
#    State Code                Area Name Sector  Total House  latrine inhouse  \
# 0         NaN                      NaN    NaN          NaN              NaN
# 1         NaN                      NaN    NaN          NaN              NaN
# 2         NaN                      NaN    NaN          NaN              NaN
# 3         NaN                      NaN    NaN          NaN              NaN
# 4         1.0  STATE - JAMMU & KASHMIR  Total     262419.0          70103.0
#
#    FP sewer system  FP septic tank  Flush other  Pit with slab  \
# 0              NaN             NaN          NaN            NaN
# 1              NaN             NaN          NaN            NaN
# 2              NaN             NaN          NaN            NaN
# 3              NaN             NaN          NaN            NaN
# 4           4876.0         12811.0      16408.0        14942.0
#
#    pit without slab  Disposal to open drain  Night soil removed by human  \
# ...

# %%
df['latrine inhouse'].plot(kind='hist',bins=100)

# %%
df.dropna(axis=0)
# Out:
#     State Code                         Area Name Sector  Total House  \
# 4          1.0           STATE - JAMMU & KASHMIR  Total     262419.0
# 5          1.0           STATE - JAMMU & KASHMIR  Rural     243707.0
# 6          1.0           STATE - JAMMU & KASHMIR  Urban      18712.0
# 7          2.0          STATE - HIMACHAL PRADESH  Total      92017.0
# 8          2.0          STATE - HIMACHAL PRADESH  Rural      84226.0
# 9          2.0          STATE - HIMACHAL PRADESH  Urban       7791.0
# 10         5.0               STATE - UTTARAKHAND  Total      63322.0
# 11         5.0               STATE - UTTARAKHAND  Rural      50630.0
# 12         5.0               STATE - UTTARAKHAND  Urban      12692.0
# 13         8.0                 STATE - RAJASTHAN  Total    1836014.0
# 14         8.0                 STATE - RAJASTHAN  Rural    1703895.0
# 15         8.0                 STATE - RAJASTHAN  Urban     132119.0
# 16         9.0             STATE - UTTAR PRADESH  Total     512649.0
# ...

# %%
df[df.Sector.str.contains("Total") == False]
# Out:
#     State Code                         Area Name Sector  Total House  \
# 5          1.0           STATE - JAMMU & KASHMIR  Rural     243707.0
# 6          1.0           STATE - JAMMU & KASHMIR  Urban      18712.0
# 8          2.0          STATE - HIMACHAL PRADESH  Rural      84226.0
# 9          2.0          STATE - HIMACHAL PRADESH  Urban       7791.0
# 11         5.0               STATE - UTTARAKHAND  Rural      50630.0
# 12         5.0               STATE - UTTARAKHAND  Urban      12692.0
# 14         8.0                 STATE - RAJASTHAN  Rural    1703895.0
# 15         8.0                 STATE - RAJASTHAN  Urban     132119.0
# 17         9.0             STATE - UTTAR PRADESH  Rural     359499.0
# 18         9.0             STATE - UTTAR PRADESH  Urban     153150.0
# 20        10.0                     STATE - BIHAR  Rural     387584.0
# 21        10.0                     STATE - BIHAR  Urban      35984.0
# 23        11.0                    STATE - SIKKIM  Rural      35756.0
# ...

# %%
boxplots=df.boxplot(return_type='axes')

# %%
from pandas.tools.plotting import scatter_matrix
#colors=[colors_palette[c] for c in df]
matrix_of_scatterplots= scatter_matrix(df,figsize=(18,18))
# Out:
# C:\Users\SrinivasaRamanujam\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import numpy as np
y=np.array(df['State Code'])
x=np.array(df['Open latrine'])

# %%
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
#from matplotlib import polyld
plt.scatter(y,x,s=[200],marker='^')
z=np.polyfit(y,x,1)
#p=np.polyld(z)
#plb.plot(x,p(x),'m-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f83ec9f6e262> in <module>()
#       2 import matplotlib.pylab as plb
#       3 #from matplotlib import polyld
# ----> 4 plt.scatter(y,x,s=[200],marker='^')
#       5 z=np.polyfit(y,x,1)
#       6 #p=np.polyld(z)
#
# NameError: name 'y' is not defined

# %%
df.cov()
# Out:
#                                  State Code   Total House  latrine inhouse  \
# State Code                        87.128090  7.933775e+05     1.396385e+05
# Total House                   793377.519101  5.545274e+11     5.791967e+10
# latrine inhouse               139638.476404  5.791967e+10     1.534985e+10
# FP sewer system                80327.226966  9.753877e+09     3.477575e+09
# FP septic tank                 51797.991011  2.364713e+10     5.133929e+09
# Flush other                    -8593.244944  5.660295e+09     1.285409e+09
# Pit with slab                  45808.696629  1.357044e+10     3.491489e+09
# pit without slab              -23129.896629  4.142545e+09     1.673297e+09
# Disposal to open drain          1329.689888  7.488098e+08     1.589917e+08
# Night soil removed by human    -6207.968539  7.444291e+07     2.443450e+07
# Night soil removed by animal   -1694.017978  3.221390e+08     1.047245e+08
# ...

# %%
print(df.corr())
# Out:
#                               State Code  Total House  latrine inhouse  \
# State Code                      1.000000     0.114140         0.120746
# Total House                     0.114140     1.000000         0.627787
# latrine inhouse                 0.120746     0.627787         1.000000
# FP sewer system                 0.222599     0.338810         0.726047
# FP septic tank                  0.118312     0.677037         0.883473
# Flush other                    -0.065849     0.543683         0.742092
# Pit with slab                   0.140616     0.522155         0.807469
# pit without slab               -0.097853     0.219678         0.533337
# Disposal to open drain          0.092902     0.655791         0.836908
# Night soil removed by human    -0.325646     0.048948         0.096566
# Night soil removed by animal   -0.106126     0.252967         0.494285
# No latrine within premises      0.103939     0.989705         0.509922
# ...
